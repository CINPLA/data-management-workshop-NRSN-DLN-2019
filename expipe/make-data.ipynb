# %%
import spikeextractors as se
import spikewidgets as sw
# %matplotlib inline
# Out:
# 10:32:37 [I] klustakwik KlustaKwik2 version 0.2.6

# %%
rec, sort = se.example_datasets.toy_example(num_channels=4, duration=120)

# %%
sw.plot_timeseries(rec, trange=[10,20])

# %%
sw.plot_rasters(sort, trange=[10,20])

# %%
sw.plot_unit_waveforms(rec, sort)

# %%
sw.plot_pca_features(rec, sort)

# %%
se.NwbRecordingExtractor.write_recording(rec, 'ecephys_1.nwb')
# Out:
# /home/mikkel/.virtualenvs/expipe/lib/python3.6/site-packages/pynwb/file.py:619: UserWarning: Date is missing timezone information. Updating to local timezone.
#   warn("Date is missing timezone information. Updating to local timezone.")

# %%
se.NwbSortingExtractor.write_sorting(sort, 'ecephys_1.nwb')
